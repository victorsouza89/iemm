# %%
folder_to_save_images = 'figs'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os, schemdraw

from evclust.ecm import ecm

# %%
# dark theme for schemdraw and matplotlib
dark_mode = True
if dark_mode:
    schemdraw.theme('dark')
    plt.style.use('dark_background')
    bg_color = 'black'
    opposite_color = 'white'
else:
    bg_color = 'white'
    opposite_color = 'black'

# %%
all_scores = {}
synth_results = {}
validation_results = {}

# %% [markdown]
# ## Easy Synth Clustering Example

# %%
experiment_name = 'two_clusters2D_synth'
folder_figs = folder_to_save_images + '/' + experiment_name

df = pd.read_csv('data/easy_synth_data.csv')
feature_names = df.columns[:-1].to_list()
features = df.iloc[:, :-1].values

number_clusters = 2
model = ecm(x=features, c=number_clusters, beta = 2,  alpha=1, delta=3, disp=False)

# model_names : (mass, F, lambda_num)
masses_to_test = {
    'easy': (model['mass_n'], model['F'][1:], 1),
}
cmap = 'Set1'
# %run -i "iemm_notebook.ipynb"
# Out:
# Exploring easy: 100%|██████████| 5/5 [00:01<00:00,  2.75lambda/s]
# Results easy: 100%|██████████| 50/50 [00:02<00:00, 21.37it/s]
# 'easy'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.915796  0.808588  0.701380  0.701452  0.701524
# -1.0  0.901122  0.819012  0.736903  0.749377  0.761850
#  0.0  0.876733  0.813867  0.751002  0.781731  0.812461
#  1.0  0.781247  0.751198  0.721149  0.811562  0.901975
#  inf  0.689432  0.669249  0.649067  0.789613  0.930160
#                                        $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$  $(x \leq 4.58)$
# $M^{-1}_{\mathcal{M}_{easy}}$       $(x \leq 4.33)$
# $M^{0}_{\mathcal{M}_{easy}}$        $(x \leq 3.92)$
# $M^{1}_{\mathcal{M}_{easy}}$        $(x \leq 3.57)$
# $M^\infty_{\mathcal{M}_{easy}}$     $(x \leq 3.01)$
#
#                                          $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$  $(x > 4.58) \wedge (x \leq 4.67)$
# $M^{-1}_{\mathcal{M}_{easy}}$       $(x > 4.33) \wedge (x \leq 4.91)$
# $M^{0}_{\mathcal{M}_{easy}}$        $(x > 3.92) \wedge (x \leq 5.13)$
# $M^{1}_{\mathcal{M}_{easy}}$        $(x \leq 5.65) \wedge (x > 3.57)$
# $M^\infty_{\mathcal{M}_{easy}}$     $(x \leq 5.99) \wedge (x > 3.01)$
#
#                                     $\omega_{2}$
# $M^{-\infty}_{\mathcal{M}_{easy}}$  $(x > 4.67)$
# $M^{-1}_{\mathcal{M}_{easy}}$       $(x > 4.91)$
# $M^{0}_{\mathcal{M}_{easy}}$        $(x > 5.13)$
# $M^{1}_{\mathcal{M}_{easy}}$        $(x > 5.65)$
# $M^\infty_{\mathcal{M}_{easy}}$     $(x > 5.99)$

# %%
# scores come from the iemm_notebook
all_scores.update(scores) # type: ignore
synth_results.update(results) # type: ignore

# %% [markdown]
# ## Synth Example with 3 Clusters

# %%
experiment_name = 'three_clusters2D_synth'
folder_figs = folder_to_save_images + '/' + experiment_name

df = pd.read_csv('data/three_clusters2D_synth.csv')
feature_names = df.columns[:-1].to_list()
features = df.iloc[:, :-1].values

number_clusters = 3
full_model = ecm(x=features, c=number_clusters, alpha=0.5, beta = 1.8, delta=10, disp=False, type='full')
simple_model = ecm(x=features, c=number_clusters, alpha=0.5, beta = 1.8, delta=10, disp=False, type='simple')
# rough_model = ecm(x=features, c=number_clusters, alpha=1, beta = 1.01, delta=10, disp=False, type='full')

# model_names : (mass, F, lambda_num)
masses_to_test = {
    'quasi-bayesian': (simple_model['mass_n'], simple_model['F'][1:], 1),
    'full': (full_model['mass_n'], full_model['F'][1:], 1),
    # 'rough': (np.round(rough_model['mass_n']), rough_model['F'][1:], 1)
}
cmap = 'personalized'

# %run -i "iemm_notebook.ipynb"
# Out:
# Exploring quasi-bayesian: 100%|██████████| 5/5 [00:04<00:00,  1.21lambda/s]
# Exploring full: 100%|██████████| 5/5 [00:07<00:00,  1.46s/lambda]
# Results quasi-bayesian: 100%|██████████| 50/50 [00:09<00:00,  5.37it/s]
# Results full: 100%|██████████| 50/50 [00:32<00:00,  1.54it/s]
# 'quasi-bayesian'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.887444  0.781227  0.728118  0.728120  0.728125
# -1.0  0.872286  0.799687  0.763387  0.772136  0.789634
#  0.0  0.866938  0.804483  0.773256  0.785821  0.810953
#  1.0  0.802770  0.761888  0.741446  0.778781  0.853452
#  inf  0.638852  0.617576  0.606938  0.708914  0.912866
#                                                                       $\omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{quasi-bayesian}}$  $(y \leq 4.54) \wedge (x \leq 4.43)$
# $M^{-1}_{\mathcal{M}_{quasi-bayesian}}$       $(y \leq 4.54) \wedge (x \leq 4.08)$
# $M^{0}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 4.69) \wedge (x \leq 3.85)$
# $M^{1}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 5.39) \wedge (x \leq 3.68)$
# $M^\infty_{\mathcal{M}_{quasi-bayesian}}$     $(y \leq 5.82) \wedge (x \leq 2.95)$
#
#                                                    $\omega_{1} \cup \omega_{2} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{quasi-bayesian}}$  $(y \leq 4.54) \wedge (x > 4.43) \wedge (x \le...
# $M^{-1}_{\mathcal{M}_{quasi-bayesian}}$       $(y \leq 4.54) \wedge (x > 4.08) \wedge (x \le...
# $M^{0}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 4.69) \wedge (x > 3.85) \wedge (x \le...
# $M^{1}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 5.39) \wedge (x \leq 5.28) \wedge (x ...
# $M^\infty_{\mathcal{M}_{quasi-bayesian}}$     $(y \leq 5.82) \wedge (x \leq 5.95) \wedge (x ...
#
#                                                                    $\omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{quasi-bayesian}}$  $(y \leq 4.54) \wedge (x > 4.48)$
# $M^{-1}_{\mathcal{M}_{quasi-bayesian}}$       $(y \leq 4.54) \wedge (x > 4.98)$
# $M^{0}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 4.69) \wedge (x > 5.09)$
# $M^{1}_{\mathcal{M}_{quasi-bayesian}}$        $(y \leq 5.39) \wedge (x > 5.28)$
# $M^\infty_{\mathcal{M}_{quasi-bayesian}}$     $(y \leq 5.82) \wedge (x > 5.95)$
#
#                                               $\omega_{1}$
# $M^{-\infty}_{\mathcal{M}_{quasi-bayesian}}$  $(y > 4.54)$
# $M^{-1}_{\mathcal{M}_{quasi-bayesian}}$       $(y > 4.54)$
# $M^{0}_{\mathcal{M}_{quasi-bayesian}}$        $(y > 4.69)$
# $M^{1}_{\mathcal{M}_{quasi-bayesian}}$        $(y > 5.39)$
# $M^\infty_{\mathcal{M}_{quasi-bayesian}}$     $(y > 5.82)$
# 'full'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.882009  0.731303  0.575128  0.593766  0.612354
# -1.0  0.881689  0.738726  0.598038  0.618498  0.638218
#  0.0  0.867413  0.745508  0.625343  0.656206  0.683719
#  1.0  0.642447  0.596290  0.542490  0.681838  0.809441
#  inf  0.621851  0.577133  0.526137  0.679054  0.818054
#                                                             $\omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(y \leq 4.62) \wedge (x \leq 3.52)$
# $M^{-1}_{\mathcal{M}_{full}}$       $(y \leq 4.62) \wedge (x \leq 3.52)$
# $M^{0}_{\mathcal{M}_{full}}$        $(y \leq 5.03) \wedge (x \leq 3.52)$
# $M^{1}_{\mathcal{M}_{full}}$        $(y \leq 4.56) \wedge (x \leq 2.72)$
# $M^\infty_{\mathcal{M}_{full}}$     $(y \leq 4.56) \wedge (x \leq 2.70)$
#
#                                                          $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(x > 3.52) \wedge (x \leq 5.47) \wedge (y \le...
# $M^{-1}_{\mathcal{M}_{full}}$       $(x > 3.52) \wedge (x \leq 5.47) \wedge (y \le...
# $M^{0}_{\mathcal{M}_{full}}$        $(x > 3.52) \wedge (x \leq 5.57) \wedge (y \le...
# $M^{1}_{\mathcal{M}_{full}}$        $(x \leq 5.44) \wedge (x > 2.72) \wedge (y \le...
# $M^\infty_{\mathcal{M}_{full}}$     $(x \leq 5.44) \wedge (x > 2.70) \wedge (y \le...
#
#                                                          $\omega_{2} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(y \leq 4.62) \wedge (x > 3.52) \wedge (y > 3...
# $M^{-1}_{\mathcal{M}_{full}}$       $(y \leq 4.62) \wedge (x > 3.52) \wedge (y > 3...
# $M^{0}_{\mathcal{M}_{full}}$        $(y \leq 5.03) \wedge (x > 3.52) \wedge (y > 4...
# $M^{1}_{\mathcal{M}_{full}}$        $(y \leq 6.13) \wedge (x \leq 5.44) \wedge (y ...
# $M^\infty_{\mathcal{M}_{full}}$     $(y \leq 6.13) \wedge (x \leq 5.44) \wedge (y ...
#
#                                          $\omega_{1} \cup \omega_{2} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(x \leq 5.47) \wedge (y > 3.88) \wedge (x > 4...
# $M^{-1}_{\mathcal{M}_{full}}$       $(y \leq 4.62) \wedge (y > 3.68) \wedge (x > 4...
# $M^{0}_{\mathcal{M}_{full}}$        $(x > 3.52) \wedge (x \leq 5.57) \wedge (y > 3...
# $M^{1}_{\mathcal{M}_{full}}$        $(x \leq 5.44) \wedge (y \leq 4.56) \wedge (x ...
# $M^\infty_{\mathcal{M}_{full}}$     $(x \leq 5.44) \wedge (y \leq 4.56) \wedge (x ...
#
#                                                          $\omega_{1} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(y \leq 4.62) \wedge (x \leq 5.47) \wedge (x ...
# $M^{-1}_{\mathcal{M}_{full}}$       $(y \leq 4.62) \wedge (x \leq 5.47) \wedge (y ...
# $M^{0}_{\mathcal{M}_{full}}$        $(y \leq 5.03) \wedge (x \leq 5.57) \wedge (y ...
# $M^{1}_{\mathcal{M}_{full}}$        $(x \leq 6.33) \wedge (y \leq 6.13) \wedge (x ...
# $M^\infty_{\mathcal{M}_{full}}$     $(x \leq 6.33) \wedge (y \leq 6.13) \wedge (x ...
#
#                                                          $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$  $(y \leq 4.62) \wedge (x > 5.47)$
# $M^{-1}_{\mathcal{M}_{full}}$       $(y \leq 4.62) \wedge (x > 5.47)$
# $M^{0}_{\mathcal{M}_{full}}$        $(y \leq 5.03) \wedge (x > 5.57)$
# $M^{1}_{\mathcal{M}_{full}}$                             $(x > 6.33)$
# $M^\infty_{\mathcal{M}_{full}}$                          $(x > 6.33)$
#
#                                                          $\omega_{3}$
# $M^{-\infty}_{\mathcal{M}_{full}}$                       $(y > 4.62)$
# $M^{-1}_{\mathcal{M}_{full}}$                            $(y > 4.62)$
# $M^{0}_{\mathcal{M}_{full}}$                             $(y > 5.03)$
# $M^{1}_{\mathcal{M}_{full}}$        $(x \leq 6.33) \wedge (y > 6.13)$
# $M^\infty_{\mathcal{M}_{full}}$     $(x \leq 6.33) \wedge (y > 6.13)$

# %%
# scores come from the iemm_notebook
all_scores.update(scores) # type: ignore
synth_results.update(results) # type: ignore

# %% [markdown]
# # Test on iris

# %%
experiment_name = 'datasets_evclust'
folder_figs = folder_to_save_images + '/' + experiment_name

# %%
# Import test data
from evclust.datasets import load_iris
df_iris = load_iris()
df_iris = df_iris.drop(['species'], axis = 1)
feature_names = df_iris.columns[:-1].to_list()
features = df_iris.iloc[:, :-1].values
number_clusters = 3
iris_model = ecm(x=features, c=number_clusters, alpha=0.5, beta = 1.8, delta=10, disp=False, type='full')
# model_names : (mass, F, lambda_num)
masses_to_test = {
    'iris': (iris_model['mass_n'], iris_model['F'][1:], 1),
}
# %run -i "iemm_notebook.ipynb"
# scores come from the iemm_notebook
all_scores.update(scores) # type: ignore
validation_results.update(results) # type: ignore
# Out:
# Exploring iris: 100%|██████████| 5/5 [00:00<00:00,  7.06lambda/s]
# Results iris: 100%|██████████| 50/50 [00:05<00:00,  8.84it/s]
# 'iris'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.872336  0.746751  0.619907  0.633296  0.646797
# -1.0  0.847368  0.776900  0.707914  0.742323  0.777439
#  0.0  0.846415  0.778853  0.712790  0.745366  0.777935
#  1.0  0.773996  0.725864  0.671799  0.749179  0.838243
#  inf  0.647244  0.595757  0.538105  0.678586  0.830750
#                                                                          $\omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                  $(x_2 \leq 3.15)$
# $M^{-1}_{\mathcal{M}_{iris}}$                                       $(x_2 \leq 3.15)$
# $M^{0}_{\mathcal{M}_{iris}}$                                        $(x_2 \leq 2.45)$
# $M^{1}_{\mathcal{M}_{iris}}$                 $(x_0 \leq 5.90) \wedge (x_2 \leq 2.45)$
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_2 \leq 4.15) \wedge (x_0 \leq 5.90) \wedge...
#
#                                                          $\omega_{2} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$              $(x_2 > 3.15) \wedge (x_2 \leq 3.95)$
# $M^{-1}_{\mathcal{M}_{iris}}$                   $(x_2 > 3.15) \wedge (x_2 \leq 3.95)$
# $M^{0}_{\mathcal{M}_{iris}}$                    $(x_2 > 2.45) \wedge (x_2 \leq 3.85)$
# $M^{1}_{\mathcal{M}_{iris}}$        $(x_2 \leq 4.15) \wedge (x_0 \leq 5.90) \wedge...
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_2 \leq 4.15) \wedge (x_0 \leq 5.90) \wedge...
#
#                                                          $\omega_{1} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$              $(x_2 > 3.95) \wedge (x_2 \leq 4.25)$
# $M^{-1}_{\mathcal{M}_{iris}}$                   $(x_2 > 3.95) \wedge (x_2 \leq 4.15)$
# $M^{0}_{\mathcal{M}_{iris}}$        $(x_2 \leq 4.35) \wedge (x_2 > 3.85) \wedge (x...
# $M^{1}_{\mathcal{M}_{iris}}$        $(x_0 \leq 7.15) \wedge (x_2 \leq 4.15) \wedge...
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_0 \leq 7.15) \wedge (x_2 \leq 4.15) \wedge...
#
#                                          $\omega_{1} \cup \omega_{2} \cup \omega_{3}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$              $(x_2 \leq 4.35) \wedge (x_2 > 4.25)$
# $M^{-1}_{\mathcal{M}_{iris}}$                   $(x_2 \leq 4.35) \wedge (x_2 > 4.15)$
# $M^{0}_{\mathcal{M}_{iris}}$        $(x_2 \leq 4.35) \wedge (x_2 > 3.85) \wedge (x...
# $M^{1}_{\mathcal{M}_{iris}}$        $(x_0 \leq 7.15) \wedge (x_2 \leq 4.65) \wedge...
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_0 \leq 7.15) \wedge (x_2 \leq 4.65) \wedge...
#
#                                                                          $\omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$              $(x_2 > 4.35) \wedge (x_2 \leq 5.25)$
# $M^{-1}_{\mathcal{M}_{iris}}$                   $(x_2 > 4.35) \wedge (x_2 \leq 5.15)$
# $M^{0}_{\mathcal{M}_{iris}}$                    $(x_2 \leq 5.15) \wedge (x_2 > 4.35)$
# $M^{1}_{\mathcal{M}_{iris}}$        $(x_0 \leq 7.15) \wedge (x_2 \leq 5.15) \wedge...
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_0 \leq 7.15) \wedge (x_2 \leq 5.25) \wedge...
#
#                                              $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$  $(x_2 > 5.25) \wedge (x_2 \leq 5.35)$
# $M^{-1}_{\mathcal{M}_{iris}}$       $(x_2 > 5.15) \wedge (x_0 \leq 7.00)$
# $M^{0}_{\mathcal{M}_{iris}}$        $(x_2 > 5.15) \wedge (x_0 \leq 7.00)$
# $M^{1}_{\mathcal{M}_{iris}}$        $(x_0 \leq 7.15) \wedge (x_2 > 5.15)$
# $M^\infty_{\mathcal{M}_{iris}}$     $(x_0 \leq 7.15) \wedge (x_2 > 5.25)$
#
#                                                           $\omega_{1}$
# $M^{-\infty}_{\mathcal{M}_{iris}}$                      $(x_2 > 5.35)$
# $M^{-1}_{\mathcal{M}_{iris}}$       $(x_2 > 5.15) \wedge (x_0 > 7.00)$
# $M^{0}_{\mathcal{M}_{iris}}$        $(x_2 > 5.15) \wedge (x_0 > 7.00)$
# $M^{1}_{\mathcal{M}_{iris}}$                            $(x_0 > 7.15)$
# $M^\infty_{\mathcal{M}_{iris}}$                         $(x_0 > 7.15)$

# %%
# Import test data
from sklearn.datasets import load_wine
wine = load_wine()
feature_names = wine.feature_names
features = np.array(wine.data)
number_clusters = 2
# wine_model = ecm(x=features, c=number_clusters, alpha=0.1, beta = 1.4, delta=5, disp=False, type='simple')
wine_model = ecm(x=features, c=number_clusters, alpha=0.05, beta = 1.4, delta=5, disp=False, type='simple')

# model_names : (mass, F, lambda_num)
masses_to_test = {
    'wine': (wine_model['mass_n'], wine_model['F'][1:], 1),
}
cmap = 'Set1'
# %run -i "iemm_notebook.ipynb"
# scores come from the iemm_notebook
all_scores.update(scores) # type: ignore
validation_results.update(results) # type: ignore

# mass_wine = wine_model['mass_n']
# mass_wine
# Out:
# Exploring wine: 100%|██████████| 5/5 [00:00<00:00, 10.41lambda/s]
# Results wine: 100%|██████████| 50/50 [00:06<00:00,  8.12it/s]
# 'wine'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.999079  0.906952  0.814824  0.814824  0.814824
# -1.0  0.994454  0.973001  0.951548  0.953907  0.956266
#  0.0  0.986110  0.971693  0.957276  0.963835  0.970394
#  1.0  0.971606  0.963952  0.956299  0.970139  0.983980
#  inf  0.623439  0.621431  0.619423  0.807394  0.995364
#                                             $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$  $(x_12 \leq 812.50)$
# $M^{-1}_{\mathcal{M}_{wine}}$       $(x_12 \leq 722.50)$
# $M^{0}_{\mathcal{M}_{wine}}$        $(x_12 \leq 716.00)$
# $M^{1}_{\mathcal{M}_{wine}}$        $(x_12 \leq 690.00)$
# $M^\infty_{\mathcal{M}_{wine}}$     $(x_12 \leq 525.00)$
#
#                                                     $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$   $(x_12 > 812.50) \wedge (x_12 \leq 832.50)$
# $M^{-1}_{\mathcal{M}_{wine}}$        $(x_12 > 722.50) \wedge (x_12 \leq 977.50)$
# $M^{0}_{\mathcal{M}_{wine}}$         $(x_12 > 716.00) \wedge (x_12 \leq 987.50)$
# $M^{1}_{\mathcal{M}_{wine}}$        $(x_12 \leq 1002.50) \wedge (x_12 > 690.00)$
# $M^\infty_{\mathcal{M}_{wine}}$     $(x_12 \leq 1192.50) \wedge (x_12 > 525.00)$
#
#                                           $\omega_{2}$
# $M^{-\infty}_{\mathcal{M}_{wine}}$   $(x_12 > 832.50)$
# $M^{-1}_{\mathcal{M}_{wine}}$        $(x_12 > 977.50)$
# $M^{0}_{\mathcal{M}_{wine}}$         $(x_12 > 987.50)$
# $M^{1}_{\mathcal{M}_{wine}}$        $(x_12 > 1002.50)$
# $M^\infty_{\mathcal{M}_{wine}}$     $(x_12 > 1192.50)$

# %%
# Import test data
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
feature_names = diabetes.feature_names
features = np.array(diabetes.data)
number_clusters = 2
diabetes_model = ecm(x=features, c=number_clusters, alpha=0.1, beta = 1.5, delta=10, disp=False, type='full')

masses_to_test = {
    'diabetes': (diabetes_model['mass_n'], diabetes_model['F'][1:], 1),
}
# %run -i "iemm_notebook.ipynb"
# scores come from the iemm_notebook
all_scores.update(scores) # type: ignore
validation_results.update(results) # type: ignore

# mass_diabetes = diabetes_model['mass_n']
# mass_diabetes
# Out:
# Exploring diabetes: 100%|██████████| 5/5 [00:00<00:00, 10.39lambda/s]
# Results diabetes: 100%|██████████| 50/50 [00:09<00:00,  5.30it/s]
# 'diabetes'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.854390  0.698233  0.542076  0.542663  0.543251
# -1.0  0.816186  0.701698  0.587211  0.642283  0.697355
#  0.0  0.783105  0.689771  0.596438  0.675605  0.754772
#  1.0  0.767454  0.680228  0.593003  0.681899  0.770795
#  inf  0.687602  0.614695  0.541787  0.674057  0.806328
#                                                                      $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                         $(x_7 \leq -0.00)$
# $M^{-1}_{\mathcal{M}_{diabetes}}$                              $(x_7 \leq -0.02)$
# $M^{0}_{\mathcal{M}_{diabetes}}$                               $(x_7 \leq -0.02)$
# $M^{1}_{\mathcal{M}_{diabetes}}$                               $(x_7 \leq -0.03)$
# $M^\infty_{\mathcal{M}_{diabetes}}$     $(x_7 \leq 0.03) \wedge (x_9 \leq -0.02)$
#
#                                                    $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$  $(x_7 > -0.00) \wedge (x_7 \leq -0.00)$
# $M^{-1}_{\mathcal{M}_{diabetes}}$        $(x_7 > -0.02) \wedge (x_8 \leq 0.00)$
# $M^{0}_{\mathcal{M}_{diabetes}}$         $(x_7 > -0.02) \wedge (x_7 \leq 0.02)$
# $M^{1}_{\mathcal{M}_{diabetes}}$         $(x_7 \leq 0.03) \wedge (x_7 > -0.03)$
# $M^\infty_{\mathcal{M}_{diabetes}}$      $(x_7 \leq 0.03) \wedge (x_9 > -0.02)$
#
#                                                                $\omega_{2}$
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                      $(x_7 > -0.00)$
# $M^{-1}_{\mathcal{M}_{diabetes}}$       $(x_7 > -0.02) \wedge (x_8 > 0.00)$
# $M^{0}_{\mathcal{M}_{diabetes}}$                             $(x_7 > 0.02)$
# $M^{1}_{\mathcal{M}_{diabetes}}$                             $(x_7 > 0.03)$
# $M^\infty_{\mathcal{M}_{diabetes}}$                          $(x_7 > 0.03)$

# %% [markdown]
# ## Test on credal-datasets-master

# %%
# look into the folder credal-datasets-master for all folders
for folder in os.listdir('credal-datasets-master'):
    if folder == '.DS_Store':
        continue
    folder_path = 'credal-datasets-master/' + folder + '/data'
    
    df_features = pd.read_csv(folder_path + '/X.csv', sep=';', header=None)
    df_y = pd.read_csv(folder_path + '/y.csv', sep=';', header=None)

    feature_names = ['feature_' + str(i) for i in range(df_features.shape[1])]
    features = df_features.values

    M = df_y.values
    number_clusters = int(np.log2(M.shape[1]) )

    F = np.zeros((M.shape[1], number_clusters))
    for experiment_name in range(M.shape[1]):
        # i to binary in number_clusters bits
        F[experiment_name] = np.array(list(bin(experiment_name)[2:].zfill(int(number_clusters))))[::-1].astype(int)
    # remove outlier metacluster
    F = F[1:]
    M = M[:,1:]
    M = M / np.sum(M, axis=1)[:, np.newaxis]

    if M.shape[1] > 5:
        # too big for now, skip
        continue

    print('----')
    print(folder)
    print('shape of features:', features.shape)
    print('shape of M:', M.shape)
    print('shape of F:', F.shape)
    print('number of clusters:', number_clusters)

    # model_names : (mass, F, lambda_num)
    masses_to_test = {
        folder: (M, F, 1)
    }

    # run the iemm notebook
    folder_figs = folder_to_save_images + '/' + folder
    if not os.path.exists(folder_figs):
        os.makedirs(folder_figs)

    cmap = 'Set1'
    # %run -i "iemm_notebook.ipynb"

    # scores come from the iemm_notebook
    all_scores.update(scores) # type: ignore
    validation_results.update(results) # type: ignore
# Out:
# ----
# Credal_Dog-2
# shape of features: (200, 42)
# shape of M: (200, 3)
# shape of F: (3, 2)
# number of clusters: 2
# Exploring Credal_Dog-2: 100%|██████████| 5/5 [00:00<00:00,  5.31lambda/s]
# Results Credal_Dog-2: 100%|██████████| 50/50 [00:15<00:00,  3.22it/s]
# 'Credal_Dog-2'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.913571  0.780357  0.647143  0.647857  0.648571
# -1.0  0.913571  0.783571  0.653571  0.656071  0.658571
#  0.0  0.913571  0.783571  0.653571  0.656071  0.658571
#  1.0  0.775714  0.682500  0.589286  0.677500  0.765714
#  inf  0.661429  0.575000  0.488571  0.632500  0.776429
#                                                                       $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{Credal_Dog-2}}$                      $(x_0 \leq -0.08)$
# $M^{-1}_{\mathcal{M}_{Credal_Dog-2}}$                           $(x_0 \leq -0.08)$
# $M^{0}_{\mathcal{M}_{Credal_Dog-2}}$                            $(x_0 \leq -0.08)$
# $M^{1}_{\mathcal{M}_{Credal_Dog-2}}$                            $(x_0 \leq -4.47)$
# $M^\infty_{\mathcal{M}_{Credal_Dog-2}}$     $(x_0 \leq 6.30) \wedge (x_20 > 0.21)$
#
#                                                          $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{Credal_Dog-2}}$     $(x_0 > -0.08) \wedge (x_0 \leq 0.41)$
# $M^{-1}_{\mathcal{M}_{Credal_Dog-2}}$          $(x_0 > -0.08) \wedge (x_0 \leq 1.62)$
# $M^{0}_{\mathcal{M}_{Credal_Dog-2}}$           $(x_0 > -0.08) \wedge (x_0 \leq 1.62)$
# $M^{1}_{\mathcal{M}_{Credal_Dog-2}}$           $(x_0 \leq 6.30) \wedge (x_0 > -4.47)$
# $M^\infty_{\mathcal{M}_{Credal_Dog-2}}$     $(x_0 \leq 6.30) \wedge (x_20 \leq 0.21)$
#
#                                               $\omega_{2}$
# $M^{-\infty}_{\mathcal{M}_{Credal_Dog-2}}$  $(x_0 > 0.41)$
# $M^{-1}_{\mathcal{M}_{Credal_Dog-2}}$       $(x_0 > 1.62)$
# $M^{0}_{\mathcal{M}_{Credal_Dog-2}}$        $(x_0 > 1.62)$
# $M^{1}_{\mathcal{M}_{Credal_Dog-2}}$        $(x_0 > 6.30)$
# $M^\infty_{\mathcal{M}_{Credal_Dog-2}}$     $(x_0 > 6.30)$
# ----
# Credal_Bird-2
# shape of features: (40, 17)
# shape of M: (40, 3)
# shape of F: (3, 2)
# number of clusters: 2
# Exploring Credal_Bird-2: 100%|██████████| 5/5 [00:00<00:00, 15.99lambda/s]
# Results Credal_Bird-2: 100%|██████████| 50/50 [00:02<00:00, 24.50it/s]
# 'Credal_Bird-2'
#           -inf      -1.0       0.0       1.0       inf
# -inf  0.864286  0.658929  0.453571  0.458929  0.464286
# -1.0  0.864286  0.667857  0.471429  0.480357  0.489286
#  0.0  0.750000  0.669643  0.589286  0.694643  0.800000
#  1.0  0.714286  0.651786  0.589286  0.726786  0.864286
#  inf  0.714286  0.651786  0.589286  0.726786  0.864286
#                                                                        $\omega_{1}$  \
# $M^{-\infty}_{\mathcal{M}_{Credal_Bird-2}}$                      $(x_0 \leq -1.88)$
# $M^{-1}_{\mathcal{M}_{Credal_Bird-2}}$                           $(x_0 \leq -1.88)$
# $M^{0}_{\mathcal{M}_{Credal_Bird-2}}$        $(x_0 \leq 5.10) \wedge (x_4 > -0.09)$
# $M^{1}_{\mathcal{M}_{Credal_Bird-2}}$         $(x_0 \leq 5.10) \wedge (x_4 > 1.46)$
# $M^\infty_{\mathcal{M}_{Credal_Bird-2}}$      $(x_0 \leq 5.10) \wedge (x_4 > 1.46)$
#
#                                                           $\omega_{1} \cup \omega_{2}$  \
# $M^{-\infty}_{\mathcal{M}_{Credal_Bird-2}}$    $(x_0 > -1.88) \wedge (x_0 \leq -0.74)$
# $M^{-1}_{\mathcal{M}_{Credal_Bird-2}}$          $(x_0 \leq 0.84) \wedge (x_0 > -1.88)$
# $M^{0}_{\mathcal{M}_{Credal_Bird-2}}$        $(x_0 \leq 5.10) \wedge (x_4 \leq -0.09)$
# $M^{1}_{\mathcal{M}_{Credal_Bird-2}}$         $(x_0 \leq 5.10) \wedge (x_4 \leq 1.46)$
# $M^\infty_{\mathcal{M}_{Credal_Bird-2}}$      $(x_0 \leq 5.10) \wedge (x_4 \leq 1.46)$
#
#                                                 $\omega_{2}$
# $M^{-\infty}_{\mathcal{M}_{Credal_Bird-2}}$  $(x_0 > -0.74)$
# $M^{-1}_{\mathcal{M}_{Credal_Bird-2}}$        $(x_0 > 0.84)$
# $M^{0}_{\mathcal{M}_{Credal_Bird-2}}$         $(x_0 > 5.10)$
# $M^{1}_{\mathcal{M}_{Credal_Bird-2}}$         $(x_0 > 5.10)$
# $M^\infty_{\mathcal{M}_{Credal_Bird-2}}$      $(x_0 > 5.10)$

# %% [markdown]
# ## Exporting Results

# %%
def dict_to_table(original_dict):
    keys = original_dict.keys()
    # for all key get what is after the last underscore
    index = list(set([key.split('_')[-1] for key in keys]))
    index = [round(float(i), 2) for i in index]
    
    # for all key get what is before the last underscore
    name_exp = list(set([key.split('_')[-2] for key in keys]))
    # for all key get what is before the last underscore
    name_dataset = list(set(["_".join(key.split('_')[:-2]) for key in keys]))
    
    columns = pd.MultiIndex.from_product([name_dataset, name_exp], names=['name_dataset', 'lambda'])

    # create a dataframe with the index and columns
    df_scores = pd.DataFrame(index=index, columns=columns)
    # fill the dataframe with the scores
    for key in keys:
        # get the value of the score
        value = original_dict[key]
        # get the index and column
        index = key.split('_')[-1]
        index = round(float(index), 2)
        lambda_value = key.split('_')[-2]
        name_exp = "_".join(key.split('_')[:-2])
        # fill the dataframe
        df_scores.loc[index, (name_exp, lambda_value)] = value

    # order columns alphabetically
    df_scores = df_scores.reindex(sorted(df_scores.columns), axis=1)
    # order index 
    df_scores = df_scores.reindex(sorted(df_scores.index), axis=0)
    
    return df_scores

# %%
def rename_M(name):
    if "quasi-bayesian"== name:
        return "q-bay"
    elif "_" in name:
        split1 = name.split('-')
        split2 = split1[0].split('_')
        
        # join the first letter of each split2
        split2 = [s[0] for s in split2]
        return "".join(split2) + "-" + split1[1]
    return name


for score in all_scores:
    scores_df = pd.DataFrame(all_scores[score])
    format_lambda = lambda x: '{:,.0f}'.format(x) if np.abs(x) < np.inf else r'\infty' if x > 0 else r'-\infty'
    scores_df.columns = [r'$\mathcal{R}_{\mathcal{M}_{'+rename_M(score)+r'}, \mathcal{U}^{' + format_lambda(c) + '}}$' for c in scores_df.columns]
    scores_df.index = [r'$M^{'+ format_lambda(i) +r'}_{\mathcal{M}_{'+rename_M(score)+r'}}$' for i in scores_df.index]
    display(scores_df)

    # latex format
    latex_table = scores_df.to_latex(escape=False, index=True, column_format='|l' + '|c' * (len(scores_df.columns)) + '|') 

    # Find the maximum value in each column and apply bold formatting
    for col in scores_df.columns:
        max_value = scores_df[col].max()
        latex_table = latex_table.replace(
            f"{max_value:.6f}", f"\\textbf{{{max_value:.6f}}}"
        )

    # Add horizontal and vertical lines to the header
    latex_table = latex_table.replace("\\toprule", "\\toprule\n\\hline")
    latex_table = latex_table.replace("\\midrule", "\\hline\n\\midrule")
    latex_table = latex_table.replace("\\bottomrule", "\\hline\n\\bottomrule")

    # save the table
    with open(folder_to_save_images + '/' + score + '_scores.tex', 'w') as f:
        f.write(latex_table)
# Out:
#                                     $\mathcal{R}_{\mathcal{M}_{easy}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$                                           0.915796
# $M^{-1}_{\mathcal{M}_{easy}}$                                                0.901122
# $M^{0}_{\mathcal{M}_{easy}}$                                                 0.876733
# $M^{1}_{\mathcal{M}_{easy}}$                                                 0.781247
# $M^{\infty}_{\mathcal{M}_{easy}}$                                            0.689432
#
#                                     $\mathcal{R}_{\mathcal{M}_{easy}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$                                           0.808588
# $M^{-1}_{\mathcal{M}_{easy}}$                                                0.819012
# $M^{0}_{\mathcal{M}_{easy}}$                                                 0.813867
# $M^{1}_{\mathcal{M}_{easy}}$                                                 0.751198
# $M^{\infty}_{\mathcal{M}_{easy}}$                                            0.669249
#
#                                     $\mathcal{R}_{\mathcal{M}_{easy}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$                                           0.701380
# $M^{-1}_{\mathcal{M}_{easy}}$                                                0.736903
# $M^{0}_{\mathcal{M}_{easy}}$                                                 0.751002
# $M^{1}_{\mathcal{M}_{easy}}$                                                 0.721149
# $M^{\infty}_{\mathcal{M}_{easy}}$                                            0.649067
#
#                                     $\mathcal{R}_{\mathcal{M}_{easy}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{easy}}$                                           0.701452
# $M^{-1}_{\mathcal{M}_{easy}}$                                                0.749377
# $M^{0}_{\mathcal{M}_{easy}}$                                                 0.781731
# $M^{1}_{\mathcal{M}_{easy}}$                                                 0.811562
# $M^{\infty}_{\mathcal{M}_{easy}}$                                            0.789613
#
#                                     $\mathcal{R}_{\mathcal{M}_{easy}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{easy}}$                                           0.701524
# $M^{-1}_{\mathcal{M}_{easy}}$                                                0.761850
# $M^{0}_{\mathcal{M}_{easy}}$                                                 0.812461
# $M^{1}_{\mathcal{M}_{easy}}$                                                 0.901975
# $M^{\infty}_{\mathcal{M}_{easy}}$                                            0.930160
#                                      $\mathcal{R}_{\mathcal{M}_{q-bay}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{q-bay}}$                                           0.887444
# $M^{-1}_{\mathcal{M}_{q-bay}}$                                                0.872286
# $M^{0}_{\mathcal{M}_{q-bay}}$                                                 0.866938
# $M^{1}_{\mathcal{M}_{q-bay}}$                                                 0.802770
# $M^{\infty}_{\mathcal{M}_{q-bay}}$                                            0.638852
#
#                                      $\mathcal{R}_{\mathcal{M}_{q-bay}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{q-bay}}$                                           0.781227
# $M^{-1}_{\mathcal{M}_{q-bay}}$                                                0.799687
# $M^{0}_{\mathcal{M}_{q-bay}}$                                                 0.804483
# $M^{1}_{\mathcal{M}_{q-bay}}$                                                 0.761888
# $M^{\infty}_{\mathcal{M}_{q-bay}}$                                            0.617576
#
#                                      $\mathcal{R}_{\mathcal{M}_{q-bay}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{q-bay}}$                                           0.728118
# $M^{-1}_{\mathcal{M}_{q-bay}}$                                                0.763387
# $M^{0}_{\mathcal{M}_{q-bay}}$                                                 0.773256
# $M^{1}_{\mathcal{M}_{q-bay}}$                                                 0.741446
# $M^{\infty}_{\mathcal{M}_{q-bay}}$                                            0.606938
#
#                                      $\mathcal{R}_{\mathcal{M}_{q-bay}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{q-bay}}$                                           0.728120
# $M^{-1}_{\mathcal{M}_{q-bay}}$                                                0.772136
# $M^{0}_{\mathcal{M}_{q-bay}}$                                                 0.785821
# $M^{1}_{\mathcal{M}_{q-bay}}$                                                 0.778781
# $M^{\infty}_{\mathcal{M}_{q-bay}}$                                            0.708914
#
#                                      $\mathcal{R}_{\mathcal{M}_{q-bay}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{q-bay}}$                                           0.728125
# $M^{-1}_{\mathcal{M}_{q-bay}}$                                                0.789634
# $M^{0}_{\mathcal{M}_{q-bay}}$                                                 0.810953
# $M^{1}_{\mathcal{M}_{q-bay}}$                                                 0.853452
# $M^{\infty}_{\mathcal{M}_{q-bay}}$                                            0.912866
#                                     $\mathcal{R}_{\mathcal{M}_{full}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$                                           0.882009
# $M^{-1}_{\mathcal{M}_{full}}$                                                0.881689
# $M^{0}_{\mathcal{M}_{full}}$                                                 0.867413
# $M^{1}_{\mathcal{M}_{full}}$                                                 0.642447
# $M^{\infty}_{\mathcal{M}_{full}}$                                            0.621851
#
#                                     $\mathcal{R}_{\mathcal{M}_{full}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$                                           0.731303
# $M^{-1}_{\mathcal{M}_{full}}$                                                0.738726
# $M^{0}_{\mathcal{M}_{full}}$                                                 0.745508
# $M^{1}_{\mathcal{M}_{full}}$                                                 0.596290
# $M^{\infty}_{\mathcal{M}_{full}}$                                            0.577133
#
#                                     $\mathcal{R}_{\mathcal{M}_{full}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$                                           0.575128
# $M^{-1}_{\mathcal{M}_{full}}$                                                0.598038
# $M^{0}_{\mathcal{M}_{full}}$                                                 0.625343
# $M^{1}_{\mathcal{M}_{full}}$                                                 0.542490
# $M^{\infty}_{\mathcal{M}_{full}}$                                            0.526137
#
#                                     $\mathcal{R}_{\mathcal{M}_{full}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{full}}$                                           0.593766
# $M^{-1}_{\mathcal{M}_{full}}$                                                0.618498
# $M^{0}_{\mathcal{M}_{full}}$                                                 0.656206
# $M^{1}_{\mathcal{M}_{full}}$                                                 0.681838
# $M^{\infty}_{\mathcal{M}_{full}}$                                            0.679054
#
#                                     $\mathcal{R}_{\mathcal{M}_{full}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{full}}$                                           0.612354
# $M^{-1}_{\mathcal{M}_{full}}$                                                0.638218
# $M^{0}_{\mathcal{M}_{full}}$                                                 0.683719
# $M^{1}_{\mathcal{M}_{full}}$                                                 0.809441
# $M^{\infty}_{\mathcal{M}_{full}}$                                            0.818054
#                                     $\mathcal{R}_{\mathcal{M}_{iris}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                           0.872336
# $M^{-1}_{\mathcal{M}_{iris}}$                                                0.847368
# $M^{0}_{\mathcal{M}_{iris}}$                                                 0.846415
# $M^{1}_{\mathcal{M}_{iris}}$                                                 0.773996
# $M^{\infty}_{\mathcal{M}_{iris}}$                                            0.647244
#
#                                     $\mathcal{R}_{\mathcal{M}_{iris}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                           0.746751
# $M^{-1}_{\mathcal{M}_{iris}}$                                                0.776900
# $M^{0}_{\mathcal{M}_{iris}}$                                                 0.778853
# $M^{1}_{\mathcal{M}_{iris}}$                                                 0.725864
# $M^{\infty}_{\mathcal{M}_{iris}}$                                            0.595757
#
#                                     $\mathcal{R}_{\mathcal{M}_{iris}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                           0.619907
# $M^{-1}_{\mathcal{M}_{iris}}$                                                0.707914
# $M^{0}_{\mathcal{M}_{iris}}$                                                 0.712790
# $M^{1}_{\mathcal{M}_{iris}}$                                                 0.671799
# $M^{\infty}_{\mathcal{M}_{iris}}$                                            0.538105
#
#                                     $\mathcal{R}_{\mathcal{M}_{iris}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                           0.633296
# $M^{-1}_{\mathcal{M}_{iris}}$                                                0.742323
# $M^{0}_{\mathcal{M}_{iris}}$                                                 0.745366
# $M^{1}_{\mathcal{M}_{iris}}$                                                 0.749179
# $M^{\infty}_{\mathcal{M}_{iris}}$                                            0.678586
#
#                                     $\mathcal{R}_{\mathcal{M}_{iris}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{iris}}$                                           0.646797
# $M^{-1}_{\mathcal{M}_{iris}}$                                                0.777439
# $M^{0}_{\mathcal{M}_{iris}}$                                                 0.777935
# $M^{1}_{\mathcal{M}_{iris}}$                                                 0.838243
# $M^{\infty}_{\mathcal{M}_{iris}}$                                            0.830750
#                                     $\mathcal{R}_{\mathcal{M}_{wine}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$                                           0.999079
# $M^{-1}_{\mathcal{M}_{wine}}$                                                0.994454
# $M^{0}_{\mathcal{M}_{wine}}$                                                 0.986110
# $M^{1}_{\mathcal{M}_{wine}}$                                                 0.971606
# $M^{\infty}_{\mathcal{M}_{wine}}$                                            0.623439
#
#                                     $\mathcal{R}_{\mathcal{M}_{wine}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$                                           0.906952
# $M^{-1}_{\mathcal{M}_{wine}}$                                                0.973001
# $M^{0}_{\mathcal{M}_{wine}}$                                                 0.971693
# $M^{1}_{\mathcal{M}_{wine}}$                                                 0.963952
# $M^{\infty}_{\mathcal{M}_{wine}}$                                            0.621431
#
#                                     $\mathcal{R}_{\mathcal{M}_{wine}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$                                           0.814824
# $M^{-1}_{\mathcal{M}_{wine}}$                                                0.951548
# $M^{0}_{\mathcal{M}_{wine}}$                                                 0.957276
# $M^{1}_{\mathcal{M}_{wine}}$                                                 0.956299
# $M^{\infty}_{\mathcal{M}_{wine}}$                                            0.619423
#
#                                     $\mathcal{R}_{\mathcal{M}_{wine}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{wine}}$                                           0.814824
# $M^{-1}_{\mathcal{M}_{wine}}$                                                0.953907
# $M^{0}_{\mathcal{M}_{wine}}$                                                 0.963835
# $M^{1}_{\mathcal{M}_{wine}}$                                                 0.970139
# $M^{\infty}_{\mathcal{M}_{wine}}$                                            0.807394
#
#                                     $\mathcal{R}_{\mathcal{M}_{wine}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{wine}}$                                           0.814824
# $M^{-1}_{\mathcal{M}_{wine}}$                                                0.956266
# $M^{0}_{\mathcal{M}_{wine}}$                                                 0.970394
# $M^{1}_{\mathcal{M}_{wine}}$                                                 0.983980
# $M^{\infty}_{\mathcal{M}_{wine}}$                                            0.995364
#                                         $\mathcal{R}_{\mathcal{M}_{diabetes}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                                           0.854390
# $M^{-1}_{\mathcal{M}_{diabetes}}$                                                0.816186
# $M^{0}_{\mathcal{M}_{diabetes}}$                                                 0.783105
# $M^{1}_{\mathcal{M}_{diabetes}}$                                                 0.767454
# $M^{\infty}_{\mathcal{M}_{diabetes}}$                                            0.687602
#
#                                         $\mathcal{R}_{\mathcal{M}_{diabetes}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                                           0.698233
# $M^{-1}_{\mathcal{M}_{diabetes}}$                                                0.701698
# $M^{0}_{\mathcal{M}_{diabetes}}$                                                 0.689771
# $M^{1}_{\mathcal{M}_{diabetes}}$                                                 0.680228
# $M^{\infty}_{\mathcal{M}_{diabetes}}$                                            0.614695
#
#                                         $\mathcal{R}_{\mathcal{M}_{diabetes}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                                           0.542076
# $M^{-1}_{\mathcal{M}_{diabetes}}$                                                0.587211
# $M^{0}_{\mathcal{M}_{diabetes}}$                                                 0.596438
# $M^{1}_{\mathcal{M}_{diabetes}}$                                                 0.593003
# $M^{\infty}_{\mathcal{M}_{diabetes}}$                                            0.541787
#
#                                         $\mathcal{R}_{\mathcal{M}_{diabetes}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                                           0.542663
# $M^{-1}_{\mathcal{M}_{diabetes}}$                                                0.642283
# $M^{0}_{\mathcal{M}_{diabetes}}$                                                 0.675605
# $M^{1}_{\mathcal{M}_{diabetes}}$                                                 0.681899
# $M^{\infty}_{\mathcal{M}_{diabetes}}$                                            0.674057
#
#                                         $\mathcal{R}_{\mathcal{M}_{diabetes}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{diabetes}}$                                           0.543251
# $M^{-1}_{\mathcal{M}_{diabetes}}$                                                0.697355
# $M^{0}_{\mathcal{M}_{diabetes}}$                                                 0.754772
# $M^{1}_{\mathcal{M}_{diabetes}}$                                                 0.770795
# $M^{\infty}_{\mathcal{M}_{diabetes}}$                                            0.806328
#                                     $\mathcal{R}_{\mathcal{M}_{CD-2}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{CD-2}}$                                           0.913571
# $M^{-1}_{\mathcal{M}_{CD-2}}$                                                0.913571
# $M^{0}_{\mathcal{M}_{CD-2}}$                                                 0.913571
# $M^{1}_{\mathcal{M}_{CD-2}}$                                                 0.775714
# $M^{\infty}_{\mathcal{M}_{CD-2}}$                                            0.661429
#
#                                     $\mathcal{R}_{\mathcal{M}_{CD-2}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{CD-2}}$                                           0.780357
# $M^{-1}_{\mathcal{M}_{CD-2}}$                                                0.783571
# $M^{0}_{\mathcal{M}_{CD-2}}$                                                 0.783571
# $M^{1}_{\mathcal{M}_{CD-2}}$                                                 0.682500
# $M^{\infty}_{\mathcal{M}_{CD-2}}$                                            0.575000
#
#                                     $\mathcal{R}_{\mathcal{M}_{CD-2}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{CD-2}}$                                           0.647143
# $M^{-1}_{\mathcal{M}_{CD-2}}$                                                0.653571
# $M^{0}_{\mathcal{M}_{CD-2}}$                                                 0.653571
# $M^{1}_{\mathcal{M}_{CD-2}}$                                                 0.589286
# $M^{\infty}_{\mathcal{M}_{CD-2}}$                                            0.488571
#
#                                     $\mathcal{R}_{\mathcal{M}_{CD-2}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{CD-2}}$                                           0.647857
# $M^{-1}_{\mathcal{M}_{CD-2}}$                                                0.656071
# $M^{0}_{\mathcal{M}_{CD-2}}$                                                 0.656071
# $M^{1}_{\mathcal{M}_{CD-2}}$                                                 0.677500
# $M^{\infty}_{\mathcal{M}_{CD-2}}$                                            0.632500
#
#                                     $\mathcal{R}_{\mathcal{M}_{CD-2}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{CD-2}}$                                           0.648571
# $M^{-1}_{\mathcal{M}_{CD-2}}$                                                0.658571
# $M^{0}_{\mathcal{M}_{CD-2}}$                                                 0.658571
# $M^{1}_{\mathcal{M}_{CD-2}}$                                                 0.765714
# $M^{\infty}_{\mathcal{M}_{CD-2}}$                                            0.776429
#                                     $\mathcal{R}_{\mathcal{M}_{CB-2}, \mathcal{U}^{-\infty}}$  \
# $M^{-\infty}_{\mathcal{M}_{CB-2}}$                                           0.864286
# $M^{-1}_{\mathcal{M}_{CB-2}}$                                                0.864286
# $M^{0}_{\mathcal{M}_{CB-2}}$                                                 0.750000
# $M^{1}_{\mathcal{M}_{CB-2}}$                                                 0.714286
# $M^{\infty}_{\mathcal{M}_{CB-2}}$                                            0.714286
#
#                                     $\mathcal{R}_{\mathcal{M}_{CB-2}, \mathcal{U}^{-1}}$  \
# $M^{-\infty}_{\mathcal{M}_{CB-2}}$                                           0.658929
# $M^{-1}_{\mathcal{M}_{CB-2}}$                                                0.667857
# $M^{0}_{\mathcal{M}_{CB-2}}$                                                 0.669643
# $M^{1}_{\mathcal{M}_{CB-2}}$                                                 0.651786
# $M^{\infty}_{\mathcal{M}_{CB-2}}$                                            0.651786
#
#                                     $\mathcal{R}_{\mathcal{M}_{CB-2}, \mathcal{U}^{0}}$  \
# $M^{-\infty}_{\mathcal{M}_{CB-2}}$                                           0.453571
# $M^{-1}_{\mathcal{M}_{CB-2}}$                                                0.471429
# $M^{0}_{\mathcal{M}_{CB-2}}$                                                 0.589286
# $M^{1}_{\mathcal{M}_{CB-2}}$                                                 0.589286
# $M^{\infty}_{\mathcal{M}_{CB-2}}$                                            0.589286
#
#                                     $\mathcal{R}_{\mathcal{M}_{CB-2}, \mathcal{U}^{1}}$  \
# $M^{-\infty}_{\mathcal{M}_{CB-2}}$                                           0.458929
# $M^{-1}_{\mathcal{M}_{CB-2}}$                                                0.480357
# $M^{0}_{\mathcal{M}_{CB-2}}$                                                 0.694643
# $M^{1}_{\mathcal{M}_{CB-2}}$                                                 0.726786
# $M^{\infty}_{\mathcal{M}_{CB-2}}$                                            0.726786
#
#                                     $\mathcal{R}_{\mathcal{M}_{CB-2}, \mathcal{U}^{\infty}}$
# $M^{-\infty}_{\mathcal{M}_{CB-2}}$                                           0.464286
# $M^{-1}_{\mathcal{M}_{CB-2}}$                                                0.489286
# $M^{0}_{\mathcal{M}_{CB-2}}$                                                 0.800000
# $M^{1}_{\mathcal{M}_{CB-2}}$                                                 0.864286
# $M^{\infty}_{\mathcal{M}_{CB-2}}$                                            0.864286

# %%
for results_name, all_results in zip(['synth_results', 'validation_results'], [synth_results, validation_results]):
    all_results.keys()
    n_cols = 3
    n_rows = int(np.ceil(len(all_results) / n_cols))
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(6*n_cols, 4*n_rows), sharex='all')
    axes = axes.flatten()

    i = 0
    for experiment_name, result in all_results.items():
        # y_label = r'$\mathcal{R}_{\mathcal{M}, \mathcal{U}^{\lambda}}$'
        y_label = r'representativeness'

        imm = result['IMM']
        iemm = result['IEMM']

        ax = axes[i]

        ax.plot(iemm[:, 0], iemm[:, 1], label='IEMM', color='tab:blue', linewidth=3)
        ax.plot(imm[:, 0], imm[:, 1], label='IMM', color='tab:orange')

        ax.set_title('dataset '+experiment_name, fontsize=14)
        ax.set_xlabel(r'$\lambda$', fontsize=12)
        ax.set_ylabel(y_label, fontsize=12)
        ax.legend(fontsize=12)
        i += 1

    # save figures as pdf
    plt.tight_layout()
    plt.savefig(folder_to_save_images + '/' + results_name + '_all_results.pdf', bbox_inches='tight')
    plt.show()
